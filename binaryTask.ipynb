# %%
import pandas as pd

# %%
raw_df = pd.read_csv("binary/X.csv", header=None)

# %%
# Put wavelengths as columns headers
wavelengths = pd.read_csv("binary/Wavelength.csv", header=None)
wavelengths_df = raw_df.rename(columns=wavelengths.T.loc[0])

# %%
y = pd.read_csv("binary/y.csv", header=None)

# Turn pandas rows into single vector
y = y[0]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(wavelengths_df, y, test_size = 0.3, random_state=42)

# %%
# Look at data for cleaning

# %%
test_data = pd.read_csv("multiclass/XtoClassify.csv", header=None)
test_data = test_data.rename(columns=wavelengths.T.loc[0])

# %%
for i,row in test_data.iterrows():
    row.plot()
plt.show()

# %%
# Visualise data
import matplotlib.pyplot as plt

# %%
for i,row in X_train.iterrows():
    if y_train[i] == 0:
        color = 'g'
    else:
        color = 'r'
    ax = row.plot(color=color, x="Wavelength", y="Spectrum")
    ax.set_xlabel("Wavelength")
    ax.set_ylabel("Spectrum")
plt.show()

# %%
X_train
# Out:
#      420.852  421.228  421.605  421.982  422.358  422.735  423.111  423.488  \
# 46    -21.29    76.30   -49.33    54.73    14.48   -65.14   -20.66    31.53
# 85     -3.95    -8.00   -45.93    46.95    38.75   -62.90    22.08     9.86
# 152   -49.01    36.74   -34.37    34.47    11.28   -66.21    -4.37    33.49
# 82    -13.71    27.85   -78.81    58.39    31.77   -39.34    11.80    41.30
# 147     3.43    52.30    -9.33    45.34    20.27   -23.27    -8.63     6.05
# 26    -17.96    66.81   -37.48    12.54     3.79   -10.61     3.83    24.09
# 155    -0.73    46.37   -12.89    55.11    26.80    -2.24    34.21    55.91
# 98    -20.66     8.44   -12.89    23.22    48.18    19.57    18.47    -3.63
# 111   -26.90   -19.41     4.30    19.36    49.67   -53.26     3.17    10.14
# 76    -17.34    41.63   -86.37    35.56     6.61   -38.07    14.97    -0.65
# 36    -18.80    -5.48   -36.30    39.81     7.94   -17.62    -2.30    18.88
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
from sklearn.model_selection import cross_val_predict

# %%
predictions = cross_val_predict(LogisticRegression(), X_train, y_train, cv=10)

# %%
accuracy_score(y_train, predictions)
# Out:
# 1.0

# %%
predictions = cross_val_predict(LogisticRegression(), X_train, y_train, cv=50)

# %%
accuracy_score(y_train, predictions)
# Out:
# 1.0

# %%
# Try training with less samples
X_samples = X_train[:10] # Only 10 samples from training data
y_samples = y_train[:10]

logreg_model = LogisticRegression()
logreg_model.fit(X_samples, y_samples)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
predictions = logreg_model.predict(X_train)
accuracy_score(y_train, predictions)
# Out:
# 1.0

# %%
# Less input features

# %%
oneX = X_train[[498.082]]

# %%
oneX_samples = oneX[:10]
l2 = LogisticRegression()
l2.fit(oneX_samples, y_train[:10])
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
predictions = l2.predict(oneX)

# %%
accuracy_score(y_train, predictions)
# Out:
# 1.0

# %%
# Try different method
from sklearn import tree

# %%
clf = tree.DecisionTreeClassifier()
clf.fit(oneX[:5], y_train[:5])
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
predictions = clf.predict(oneX)
accuracy_score(y_train, predictions)
# Out:
# 1.0
